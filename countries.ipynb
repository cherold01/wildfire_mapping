# %%
import pandas as pd
import requests
import geopandas as gpd
import folium
import numpy as np

# %%
countries = gpd.read_file('data/geoBoundariesCGAZ_ADM0.gpkg').to_crs(4326)
countries.info()
countries.crs
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          0 non-null      object
#  1   shapeGroup  218 non-null    str
#  2   shapeType   218 non-null    str
#  3   shapeName   218 non-null    str
#  4   geometry    218 non-null    geometry
# dtypes: geometry(1), object(1), str(3)
# memory usage: 8.6+ KB
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
countries_simple = countries.geometry.simplify(tolerance = 0.05)
countries_simple.info()
# Out:
# <class 'geopandas.geoseries.GeoSeries'>
# RangeIndex: 218 entries, 0 to 217
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 218 non-null    geometry
# dtypes: geometry(1)
# memory usage: 1.8 KB

# %%
countries_simple.to_file('data/countries_simple.gpkg')

# %%
countries_simple.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35e01dd5e6580f52ebcf2243bd885c6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35e01dd5e6580f52ebcf2243bd885c6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35e01dd5e6580f52ebcf2243bd885c6e = L.map(
#                 &quot;map_35e01dd5e6580f52ebcf2243bd885c6e&quot;,
#                 {
#                     center: [-3.1833038329999823, 5.684341886080802e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_35e01dd5e6580f52ebcf2243bd885c6e);
#
#
#
#
#
#             var tile_layer_5154064d62ba44c291370a35b2fb4ddb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5154064d62ba44c291370a35b2fb4ddb.addTo(map_35e01dd5e6580f52ebcf2243bd885c6e);
#
#
#             map_35e01dd5e6580f52ebcf2243bd885c6e.fitBounds(
#                 [[-90.0, -180.0], [83.63339233400004, 180.0000000000001]],
#                 {}
#             );
#
#
#         function geo_json_b5814369127b97eb2dfeaa7b07cdceed_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b5814369127b97eb2dfeaa7b07cdceed_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b5814369127b97eb2dfeaa7b07cdceed_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_b5814369127b97eb2dfeaa7b07cdceed_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b5814369127b97eb2dfeaa7b07cdceed_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b5814369127b97eb2dfeaa7b07cdceed.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b5814369127b97eb2dfeaa7b07cdceed_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b5814369127b97eb2dfeaa7b07cdceed = L.geoJson(null, {
#                 onEachFeature: geo_json_b5814369127b97eb2dfeaa7b07cdceed_onEachFeature,
#
#                 style: geo_json_b5814369127b97eb2dfeaa7b07cdceed_styler,
#                 pointToLayer: geo_json_b5814369127b97eb2dfeaa7b07cdceed_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b5814369127b97eb2dfeaa7b07cdceed_add (data) {
#             geo_json_b5814369127b97eb2dfeaa7b07cdceed
#                 .addData(data);
#         }
#             geo_json_b5814369127b97eb2dfeaa7b07cdceed_add({&quot;bbox&quot;: [-180.0, -90.0, 180.0000000000001, 83.63339233400004], &quot;features&quot;: [{&quot;bbox&quot;: [60.521093117192436, 29.377205882628814, 74.889863358485, 38.49073726671432], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[74.889863358485, 37.234079433043675], [74.74104145722762, 37.28611844952839], [74.50090211490377, 37.239268438027125], [74.45598235355524, 37.14288701532023], [74.56476610262362, 37.03304893854143], [74.53892492386
